# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}

df = pd.DataFrame(data=d)

print(df)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11

# %% [markdown]
# # Count the number of columns:

# %%
count_column = df.shape[1]
print(count_column)
# Out:
# 3

# %% [markdown]
# count the number of rows:

# %%
count_row = df.shape[0]
print(count_row)
# Out:
# 5

# %% [markdown]
# The max() function:

# %%
Average_pulse_max = max(80, 85, 90, 95, 100, 105, 110, 115, 120, 125)

print (Average_pulse_max)
# Out:
# 125

# %% [markdown]
# # The min() function

# %%
Average_pulse_min = min(80, 85, 90, 95, 100, 105, 110, 115, 120, 125)

print (Average_pulse_min)
# Out:
# 80

# %% [markdown]
# # The mean() function

# %%
Calorie_burnage = [240, 250, 260, 270, 280, 290, 300, 310, 320, 330]

Average_calorie_burnage = np.mean(Calorie_burnage)

print(Average_calorie_burnage)
# Out:
# 285.0

# %% [markdown]
# # Data Preparation

# %%
health_data = pd.read_csv("UceResultsBySchool2011-2016.csv", header=0, sep=",")
health_data
# print(health_data)
# header=0 means that the headers for the variable names are to be found in the first row 
# sep="," means that "," is used as the separator between the values
# Out:
#        YEAR      DISTRICT                                              SCHOOL  \
# 0      2011         WAKISO                                 GAYAZA HIGH SCHOOL
# 1      2011         MUKONO                                 NAMILYANGO COLLEGE
# 2      2011         MUKONO                             MT.ST.MARY'S,NAMAGUNGA
# 3      2011         WAKISO                        UGANDA MARTYRS SS,NAMUGONGO
# 4      2011  BUSHENYI MAIN                                    KITABI SEMINARY
# ...     ...            ...                                                ...
# 17634  2016          ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016          ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016          ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016          ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016          ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
#        TOTAL CANDIDATES  TOTAL DIV 1  % DIV 1  TOTAL DIV 2  % DIV 2  \
# 0                 176.0        175.0     99.4          1.0      0.6
# 1                 151.0        150.0     99.3          NaN      0.0
# 2                 153.0        151.0     98.7          2.0      1.3
# 3                 222.0        216.0     97.3          6.0      2.7
# 4                  73.0         71.0     97.3          2.0      2.7
# ...                 ...          ...      ...          ...      ...
# 17634             148.0          0.0      0.0         12.0      8.1
# 17635              68.0          0.0      0.0          2.0      2.9
# 17636             128.0          0.0      0.0          4.0      3.1
# 17637              45.0          0.0      0.0          1.0      2.2
# 17638              50.0          0.0      0.0          1.0      2.0
#
#        TOTAL DIV 3  % DIV 3  ...  MALE TOTAL DIV3  MALE % DIV3  \
# 0              NaN      0.0  ...              NaN          0.0
# 1              NaN      0.0  ...              NaN          0.0
# 2              NaN      0.0  ...              NaN          0.0
# 3              NaN      0.0  ...              NaN          0.0
# 4              NaN      0.0  ...              2.0          0.0
# ...            ...      ...  ...              ...          ...
# 17634         30.0     20.3  ...             25.0         24.0
# 17635         11.0     16.2  ...              7.0         17.5
# 17636          6.0      4.7  ...              6.0          5.8
# 17637          2.0      4.4  ...              2.0          6.5
# 17638          4.0      8.0  ...              4.0         18.2
#
#        MALE TOTAL DIV4  MALE % DIV4   MALE TOTAL DIV7   MALE % DIV7  \
# 0                  NaN           0.0               NaN          0.0
# 1                  NaN           0.0               NaN          0.0
# 2                  NaN           0.0               NaN          0.0
# 3                  NaN           0.0               NaN          0.0
# 4                  NaN           0.0               NaN          0.0
# ...                ...           ...               ...          ...
# 17634             53.0          51.0               0.0          0.0
# 17635             29.0          72.5               0.0          0.0
# 17636             54.0          51.9               1.0          1.0
# 17637             19.0          61.3               0.0          0.0
# 17638             10.0          45.5               0.0          0.0
#
#        MALE TOTAL DIV9   MALE % DIV9  MALE TOTAL X   MALE % X
# 0                   NaN          0.0            NaN       0.0
# 1                   NaN          0.0            NaN       0.7
# 2                   NaN          0.0            NaN       0.0
# 3                   NaN          0.0            NaN       0.0
# 4                   NaN          0.0            NaN       0.0
# ...                 ...          ...            ...       ...
# 17634              10.0          9.6            4.0       3.8
# 17635               3.0          7.5            0.0       0.0
# 17636              31.0         29.8            8.0       7.7
# 17637               9.0         29.0            1.0       3.2
# 17638               7.0         31.8            0.0       0.0
#
# [17639 rows x 48 columns]

# %% [markdown]
# # printing first five rows

# %%
health_data.head()
# Out:
#    YEAR      DISTRICT                        SCHOOL  TOTAL CANDIDATES  \
# 0  2011         WAKISO           GAYAZA HIGH SCHOOL             176.0
# 1  2011         MUKONO           NAMILYANGO COLLEGE             151.0
# 2  2011         MUKONO       MT.ST.MARY'S,NAMAGUNGA             153.0
# 3  2011         WAKISO  UGANDA MARTYRS SS,NAMUGONGO             222.0
# 4  2011  BUSHENYI MAIN              KITABI SEMINARY              73.0
#
#    TOTAL DIV 1  % DIV 1  TOTAL DIV 2  % DIV 2  TOTAL DIV 3  % DIV 3  ...  \
# 0        175.0     99.4          1.0      0.6          NaN      0.0  ...
# 1        150.0     99.3          NaN      0.0          NaN      0.0  ...
# 2        151.0     98.7          2.0      1.3          NaN      0.0  ...
# 3        216.0     97.3          6.0      2.7          NaN      0.0  ...
# 4         71.0     97.3          2.0      2.7          NaN      0.0  ...
#
#    MALE TOTAL DIV3  MALE % DIV3  MALE TOTAL DIV4  MALE % DIV4   \
# 0              NaN          0.0              NaN           0.0
# 1              NaN          0.0              NaN           0.0
# 2              NaN          0.0              NaN           0.0
# 3              NaN          0.0              NaN           0.0
# 4              2.0          0.0              NaN           0.0
#
#    MALE TOTAL DIV7   MALE % DIV7  MALE TOTAL DIV9   MALE % DIV9  \
# 0               NaN          0.0               NaN          0.0
# 1               NaN          0.0               NaN          0.0
# 2               NaN          0.0               NaN          0.0
# 3               NaN          0.0               NaN          0.0
# 4               NaN          0.0               NaN          0.0
#
#    MALE TOTAL X   MALE % X
# 0            NaN       0.0
# 1            NaN       0.7
# 2            NaN       0.0
# 3            NaN       0.0
# 4            NaN       0.0
#
# [5 rows x 48 columns]

# %% [markdown]
# # Data cleaning
#  Remove Blank Rows
#  dropna() function to remove the NaNs
#   axis=0 means that we want to remove all rows that have a NaN value

# %%
health_data.dropna(axis=0,inplace=True)
health_data
# Out:
#        YEAR  DISTRICT                                              SCHOOL  \
# 3197   2012      JINJA                             JINJA SECONDARY SCHOOL
# 3263   2012     WAKISO                       VICTORIA HIGH SCHOOL,NANSANA
# 3327   2012    KAMPALA                               MBUYA COLLEGE SCHOOL
# 3444   2012    KAMPALA                            KOLOLO SECONDARY SCHOOL
# 3549   2012  RUKUNGIRI                              RUKUNGIRI HIGH SCHOOL
# ...     ...        ...                                                ...
# 17634  2016      ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016      ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016      ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016      ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016      ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
#        TOTAL CANDIDATES  TOTAL DIV 1  % DIV 1  TOTAL DIV 2  % DIV 2  \
# 3197              498.0         38.0      7.6        111.0     22.3
# 3263              186.0         12.0      6.5         36.0     19.4
# 3327              107.0          6.0      5.6         21.0     19.6
# 3444              411.0         18.0      4.4         62.0     15.1
# 3549              169.0          6.0      3.6         26.0     15.4
# ...                 ...          ...      ...          ...      ...
# 17634             148.0          0.0      0.0         12.0      8.1
# 17635              68.0          0.0      0.0          2.0      2.9
# 17636             128.0          0.0      0.0          4.0      3.1
# 17637              45.0          0.0      0.0          1.0      2.2
# 17638              50.0          0.0      0.0          1.0      2.0
#
#        TOTAL DIV 3  % DIV 3  ...  MALE TOTAL DIV3  MALE % DIV3  \
# 3197         149.0     29.9  ...             84.0         29.2
# 3263          51.0     27.4  ...             24.0         26.4
# 3327          29.0     27.1  ...             11.0         19.0
# 3444         104.0     25.3  ...             49.0         23.3
# 3549          45.0     26.6  ...             19.0         30.2
# ...            ...      ...  ...              ...          ...
# 17634         30.0     20.3  ...             25.0         24.0
# 17635         11.0     16.2  ...              7.0         17.5
# 17636          6.0      4.7  ...              6.0          5.8
# 17637          2.0      4.4  ...              2.0          6.5
# 17638          4.0      8.0  ...              4.0         18.2
#
#        MALE TOTAL DIV4  MALE % DIV4   MALE TOTAL DIV7   MALE % DIV7  \
# 3197              95.0          33.0               1.0          0.3
# 3263              26.0          28.6               7.0          7.7
# 3327              26.0          44.8               2.0          3.4
# 3444              94.0          44.8               3.0          1.4
# 3549              21.0          33.3               1.0          1.6
# ...                ...           ...               ...          ...
# 17634             53.0          51.0               0.0          0.0
# 17635             29.0          72.5               0.0          0.0
# 17636             54.0          51.9               1.0          1.0
# 17637             19.0          61.3               0.0          0.0
# 17638             10.0          45.5               0.0          0.0
#
#        MALE TOTAL DIV9   MALE % DIV9  MALE TOTAL X   MALE % X
# 3197                7.0          2.4            4.0       1.4
# 3263                2.0          2.2            3.0       3.3
# 3327                1.0          1.7            1.0       1.7
# 3444               10.0          4.8            1.0       0.5
# 3549                1.0          1.6            3.0       4.8
# ...                 ...          ...            ...       ...
# 17634              10.0          9.6            4.0       3.8
# 17635               3.0          7.5            0.0       0.0
# 17636              31.0         29.8            8.0       7.7
# 17637               9.0         29.0            1.0       3.2
# 17638               7.0         31.8            0.0       0.0
#
# [3128 rows x 48 columns]

# %%
# We can use the info() function to list the data types within our data set: 
# print(health_data.info())
# We can use the astype() function to convert the data into float64.
# health_data["Average_Pulse"] = health_data['Average_Pulse'].astype(float)
# health_data["Max_Pulse"] = health_data["Max_Pulse"].astype(float)
health_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3128 entries, 3197 to 17638
# Data columns (total 48 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   YEAR                3128 non-null   int64
#  1   DISTRICT            3128 non-null   object
#  2   SCHOOL              3128 non-null   object
#  3   TOTAL CANDIDATES    3128 non-null   float64
#  4   TOTAL DIV 1         3128 non-null   float64
#  5   % DIV 1             3128 non-null   float64
#  6   TOTAL DIV 2         3128 non-null   float64
#  7   % DIV 2             3128 non-null   float64
#  8   TOTAL DIV 3         3128 non-null   float64
#  9   % DIV 3             3128 non-null   float64
#  10  TOTAL DIV 4         3128 non-null   float64
#  11  % DIV 4             3128 non-null   float64
#  12  TOTAL DIV 7         3128 non-null   float64
#  13  % DIV 7             3128 non-null   float64
#  14  TOTAL DIV 9         3128 non-null   float64
#  15  % DIV 9             3128 non-null   float64
#  16  TOTAL X             3128 non-null   float64
#  17  % X                 3128 non-null   float64
#  18  FEMALE CANDIDATES   3128 non-null   int64
#  19  FEMALE TOTAL DIV1   3128 non-null   float64
#  20  FEMALE % DIV1       3128 non-null   float64
#  21  FEMALE TOTAL DIV2   3128 non-null   float64
#  22  FEMALE % DIV2       3128 non-null   float64
#  23  FEMALE TOTAL DIV3   3128 non-null   float64
#  24  FEMALE % DIV3       3128 non-null   float64
#  25  FEMALE TOTAL DIV4   3128 non-null   float64
#  26  FEMALE % DIV4       3128 non-null   float64
#  27  FEMALE TOTAL DIV7   3128 non-null   float64
#  28  FEMALE % DIV7       3128 non-null   float64
#  29  FEMALE TOTAL DIV9   3128 non-null   float64
#  30  FEMALE % DIV9       3128 non-null   float64
#  31  FEMALE TOTAL X      3128 non-null   float64
#  32  FEMALE % X          3128 non-null   float64
#  33  MALE CANDIDATES     3128 non-null   int64
#  34  MALE TOTAL DIV1     3128 non-null   float64
#  35  MALE % DIV1         3128 non-null   float64
#  36  MALE TOTAL DIV2     3128 non-null   float64
#  37  MALE % DIV2         3128 non-null   float64
#  38  MALE TOTAL DIV3     3128 non-null   float64
#  39  MALE % DIV3         3128 non-null   float64
#  40  MALE TOTAL DIV4     3128 non-null   float64
#  41  MALE % DIV4         3128 non-null   float64
#  42  MALE TOTAL DIV7     3128 non-null   float64
#  43  MALE % DIV7         3128 non-null   float64
#  44  MALE TOTAL DIV9     3128 non-null   float64
#  45  MALE % DIV9         3128 non-null   float64
#  46  MALE TOTAL X        3128 non-null   float64
#  47  MALE % X            3128 non-null   float64
# dtypes: float64(43), int64(3), object(2)
# memory usage: 1.2+ MB

# %% [markdown]
# # Data Categories
# When we have cleaned the data set, we can start analyzing the data.
# Analyze the Data
# We can use the describe() function in Python to summarize data:

# %%
health_data.describe()
# Out:
#               YEAR  TOTAL CANDIDATES  TOTAL DIV 1      % DIV 1  TOTAL DIV 2  \
# count  3128.000000       3128.000000  3128.000000  3128.000000  3128.000000
# mean   2015.948529        101.761829     6.127877     4.985358    13.208440
# std       0.393712         71.490996    19.208289    10.596406    17.745925
# min    2012.000000          2.000000     0.000000     0.000000     0.000000
# 25%    2016.000000         53.000000     0.000000     0.000000     3.000000
# 50%    2016.000000         86.000000     1.000000     1.600000     7.000000
# 75%    2016.000000        130.000000     5.000000     4.800000    16.000000
# max    2016.000000        499.000000   430.000000   100.000000   230.000000
#
#            % DIV 2  TOTAL DIV 3      % DIV 3  TOTAL DIV 4      % DIV 4  ...  \
# count  3128.000000  3128.000000  3128.000000  3128.000000  3128.000000  ...
# mean     12.181937    19.997442    19.426758    46.869246    47.199137  ...
# std      11.233348    17.763341     9.292870    36.542783    16.190935  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       4.200000     8.000000    12.700000    22.000000    41.400000  ...
# 50%       8.700000    15.000000    18.800000    38.000000    50.700000  ...
# 75%      16.300000    27.000000    25.800000    62.000000    57.500000  ...
# max      61.200000   156.000000    60.000000   289.000000    90.000000  ...
#
#        MALE TOTAL DIV3  MALE % DIV3  MALE TOTAL DIV4  MALE % DIV4   \
# count      3128.000000  3128.000000      3128.000000   3128.000000
# mean         11.103581    21.019533        22.465153     43.379668
# std          10.117450    10.678114        18.943794     17.649871
# min           0.000000     0.000000         0.000000      0.000000
# 25%           4.000000    13.600000         9.000000     35.300000
# 50%           8.000000    20.500000        18.000000     46.350000
# 75%          15.000000    27.800000        30.000000     54.925000
# max         100.000000   100.000000       150.000000    100.000000
#
#        MALE TOTAL DIV7   MALE % DIV7  MALE TOTAL DIV9   MALE % DIV9  \
# count       3128.000000  3128.000000       3128.000000  3128.000000
# mean           0.226662     0.390441          6.199808    11.547698
# std            0.659073     1.267140          8.736305    12.031251
# min            0.000000     0.000000          0.000000     0.000000
# 25%            0.000000     0.000000          1.000000     1.600000
# 50%            0.000000     0.000000          3.000000     8.300000
# 75%            0.000000     0.000000          8.000000    17.600000
# max           15.000000    20.000000         81.000000    75.000000
#
#        MALE TOTAL X      MALE % X
# count    3128.000000  3128.000000
# mean        1.153133     2.432705
# std         1.638368     4.643836
# min         0.000000     0.000000
# 25%         0.000000     0.000000
# 50%         1.000000     1.200000
# 75%         2.000000     3.400000
# max        16.000000   100.000000
#
# [8 rows x 46 columns]

# %% [markdown]
# # Data Science - Linear Functions
# <!-- kind='line' tells us which type of plot we want. Here, we want to have a straight line
# plt.ylim() and plt.xlim() tells us what value we want the axis to start on. Here, we want the axis to begin from zero
# plt.show() shows us the output -->

# %%
health_data.plot(x ='TOTAL DIV 1', y='TOTAL DIV 2', kind='line'),
plt.ylim(ymin=0)
plt.xlim(xmin=0)

plt.show()

# %% [markdown]
# # Data Science - Slope and Intercept
# The np.polyfit() function returns the slope and intercept.
# Finding slope using python.

# %%
def slope(x1, y1, x2, y2):
  s = (y2-y1)/(x2-x1)
  return s

print(slope(80,240,90,260))
# Out:
# 2.0

# %%
x = health_data["TOTAL DIV 1"]
y = health_data["TOTAL DIV 2"]
slope_intercept = np.polyfit(x,y,1)

print(slope_intercept)
# Out:
# [ 0.50486872 10.11466637]

# %%
health_data.plot(x ='TOTAL DIV 1', y='TOTAL DIV 2', kind='line'),
plt.ylim(ymin=0, ymax=400)
plt.xlim(xmin=0, xmax=150)

plt.show()

# %%
#Find the 10% percentile for TOTAL DIV 1 
#np.percentile() is used to define that we want the 10% percentile from Max_Pulse.
Max_Pulse= health_data["TOTAL DIV 1"]
percentile10 = np.percentile(Max_Pulse, 10)
print(percentile10)
# Out:
# nan

# %% [markdown]
# # Standard Deviation
# We can use the std() function from Numpy to find the standard deviation of a variable

# %%
std = np.std(health_data)
print(std)
# Out:
# YEAR                   1.710772
# TOTAL CANDIDATES      66.962682
# TOTAL DIV 1           26.213314
# % DIV 1               13.265780
# TOTAL DIV 2           19.323533
# % DIV 2               12.799745
# TOTAL DIV 3           17.803885
# % DIV 3               10.241322
# TOTAL DIV 4           35.557688
# % DIV 4               20.025380
# TOTAL DIV 7            1.730013
# % DIV 7                1.335722
# TOTAL DIV 9           12.479465
# % DIV 9                9.096616
# TOTAL X                2.530727
# % X                    4.024530
# FEMALE CANDIDATES     35.430636
# FEMALE TOTAL DIV1     18.155170
# FEMALE % DIV1         10.847601
# FEMALE TOTAL DIV2     11.629938
# FEMALE % DIV2         13.319041
# FEMALE TOTAL DIV3      9.944237
# FEMALE % DIV3         12.617678
# FEMALE TOTAL DIV4     18.241832
# FEMALE % DIV4         22.130695
# FEMALE TOTAL DIV7      1.254627
# FEMALE % DIV7          1.568413
# FEMALE TOTAL DIV9      6.612145
# FEMALE % DIV9         11.640571
# FEMALE TOTAL X         1.393644
# FEMALE % X             4.304820
# MALE CANDIDATES       40.638841
# MALE TOTAL DIV1       16.998618
# MALE % DIV1           13.730071
# MALE TOTAL DIV2       12.530783
# MALE % DIV2           13.493478
# MALE TOTAL DIV3       10.747553
# MALE % DIV3           11.836588
# MALE TOTAL DIV4       18.530020
# MALE % DIV4           21.373385
# MALE TOTAL DIV7       15.588638
# MALE % DIV7            1.522062
# MALE TOTAL DIV9        7.048300
# MALE % DIV9            8.668514
# MALE TOTAL X           2.284129
# MALE % X               4.181905
# dtype: float64
# /home/lawrencepro/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3558: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
# Coefficient of Variation
# The coefficient of variation is used to get an idea of how large the standard deviation is.

# Mathematically, the coefficient of variation is defined as:

# Coefficient of Variation = Standard Deviation / Mean
cv = np.std(health_data) / np.mean(health_data)
print(cv)
# Out:
# YEAR                  0.000850
# TOTAL CANDIDATES      0.668881
# TOTAL DIV 1           2.533112
# % DIV 1               2.130542
# TOTAL DIV 2           1.203310
# % DIV 2               0.867854
# TOTAL DIV 3           0.789675
# % DIV 3               0.462042
# TOTAL DIV 4           0.773307
# % DIV 4               0.441298
# TOTAL DIV 7           1.653809
# % DIV 7               3.494423
# TOTAL DIV 9           1.305650
# % DIV 9               1.251850
# TOTAL X               0.952166
# % X                   1.751255
# FEMALE CANDIDATES     0.748550
# FEMALE TOTAL DIV1     3.088476
# FEMALE % DIV1         2.850617
# FEMALE TOTAL DIV2     1.468523
# FEMALE % DIV2         1.172083
# FEMALE TOTAL DIV3     0.911253
# FEMALE % DIV3         0.619195
# FEMALE TOTAL DIV4     0.754994
# FEMALE % DIV4         0.444307
# FEMALE TOTAL DIV7     2.221123
# FEMALE % DIV7         4.888015
# FEMALE TOTAL DIV9     1.184945
# FEMALE % DIV9         1.308337
# FEMALE TOTAL X        0.875604
# FEMALE % X            1.886107
# MALE CANDIDATES       0.793102
# MALE TOTAL DIV1       2.493893
# MALE % DIV1           1.915832
# MALE TOTAL DIV2       1.331128
# MALE % DIV2           0.838918
# MALE TOTAL DIV3       0.885162
# MALE % DIV3           0.531377
# MALE TOTAL DIV4       0.851943
# MALE % DIV4           0.525303
# MALE TOTAL DIV7       1.953165
# MALE % DIV7           3.559945
# MALE TOTAL DIV9       1.328693
# MALE % DIV9           1.427051
# MALE TOTAL X          1.178748
# MALE % X              1.895555
# dtype: float64
# /home/lawrencepro/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3417: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %% [markdown]
# # Variance
# # We can use the var() function from Numpy to find the variance

# %%
var = np.var(health_data)
print(var)
# Out:
# YEAR                     2.926742
# TOTAL CANDIDATES      4484.000817
# TOTAL DIV 1            687.137849
# % DIV 1                175.980920
# TOTAL DIV 2            373.398930
# % DIV 2                163.833484
# TOTAL DIV 3            316.978327
# % DIV 3                104.884686
# TOTAL DIV 4           1264.349190
# % DIV 4                401.015847
# TOTAL DIV 7              2.992945
# % DIV 7                  1.784153
# TOTAL DIV 9            155.737042
# % DIV 9                 82.748424
# TOTAL X                  6.404578
# % X                     16.196841
# FEMALE CANDIDATES     1255.330000
# FEMALE TOTAL DIV1      329.610189
# FEMALE % DIV1          117.670449
# FEMALE TOTAL DIV2      135.255448
# FEMALE % DIV2          177.396851
# FEMALE TOTAL DIV3       98.887852
# FEMALE % DIV3          159.205793
# FEMALE TOTAL DIV4      332.764438
# FEMALE % DIV4          489.767646
# FEMALE TOTAL DIV7        1.574089
# FEMALE % DIV7            2.459920
# FEMALE TOTAL DIV9       43.720460
# FEMALE % DIV9          135.502904
# FEMALE TOTAL X           1.942244
# FEMALE % X              18.531476
# MALE CANDIDATES       1651.515438
# MALE TOTAL DIV1        288.953030
# MALE % DIV1            188.514863
# MALE TOTAL DIV2        157.020527
# MALE % DIV2            182.073960
# MALE TOTAL DIV3        115.509897
# MALE % DIV3            140.104820
# MALE TOTAL DIV4        343.361639
# MALE % DIV4            456.821594
# MALE TOTAL DIV7        243.005641
# MALE % DIV7              2.316673
# MALE TOTAL DIV9         49.678532
# MALE % DIV9             75.143134
# MALE TOTAL X             5.217246
# MALE % X                17.488330
# dtype: float64
# /home/lawrencepro/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3700: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
var_full = np.var(health_data)
print(var_full)
# Out:
# YEAR                     2.926742
# TOTAL CANDIDATES      4484.000817
# TOTAL DIV 1            687.137849
# % DIV 1                175.980920
# TOTAL DIV 2            373.398930
# % DIV 2                163.833484
# TOTAL DIV 3            316.978327
# % DIV 3                104.884686
# TOTAL DIV 4           1264.349190
# % DIV 4                401.015847
# TOTAL DIV 7              2.992945
# % DIV 7                  1.784153
# TOTAL DIV 9            155.737042
# % DIV 9                 82.748424
# TOTAL X                  6.404578
# % X                     16.196841
# FEMALE CANDIDATES     1255.330000
# FEMALE TOTAL DIV1      329.610189
# FEMALE % DIV1          117.670449
# FEMALE TOTAL DIV2      135.255448
# FEMALE % DIV2          177.396851
# FEMALE TOTAL DIV3       98.887852
# FEMALE % DIV3          159.205793
# FEMALE TOTAL DIV4      332.764438
# FEMALE % DIV4          489.767646
# FEMALE TOTAL DIV7        1.574089
# FEMALE % DIV7            2.459920
# FEMALE TOTAL DIV9       43.720460
# FEMALE % DIV9          135.502904
# FEMALE TOTAL X           1.942244
# FEMALE % X              18.531476
# MALE CANDIDATES       1651.515438
# MALE TOTAL DIV1        288.953030
# MALE % DIV1            188.514863
# MALE TOTAL DIV2        157.020527
# MALE % DIV2            182.073960
# MALE TOTAL DIV3        115.509897
# MALE % DIV3            140.104820
# MALE TOTAL DIV4        343.361639
# MALE % DIV4            456.821594
# MALE TOTAL DIV7        243.005641
# MALE % DIV7              2.316673
# MALE TOTAL DIV9         49.678532
# MALE % DIV9             75.143134
# MALE TOTAL X             5.217246
# MALE % X                17.488330
# dtype: float64

# %% [markdown]
# # Correlation
# Correlation measures the relationship between two variables.
# The correlation coefficient measures the relationship between two variables.
# The correlation coefficient can never be less than -1 or higher than 1.
#
# 1 = there is a perfect linear relationship between the variables (like Average_Pulse against Calorie_Burnage)
# 0 = there is no linear relationship between the variables
# -1 = there is a perfect negative linear relationship between the variables (e.g. Less hours worked, leads to higher calorie burnage during a training session)

# %%
health_data.plot(x ='TOTAL DIV 1', y='TOTAL DIV 2', kind='scatter')
plt.show()

# %% [markdown]
# # Correlation Matrix
# We can use the corr() function in Python to create a correlation matrix.
# We also use the round() function to round the output to two decimals:

# %%
Corr_Matrix = round(health_data.corr(),2)
print(Corr_Matrix)
# Out:
#                     YEAR  TOTAL CANDIDATES  TOTAL DIV 1  % DIV 1  TOTAL DIV 2  \
# YEAR                1.00              0.00        -0.05     0.01        -0.06
# TOTAL CANDIDATES    0.00              1.00         0.35     0.15         0.56
# TOTAL DIV 1        -0.05              0.35         1.00     0.82         0.49
# % DIV 1             0.01              0.15         0.82     1.00         0.42
# TOTAL DIV 2        -0.06              0.56         0.49     0.42         1.00
# % DIV 2            -0.07              0.07         0.27     0.47         0.67
# TOTAL DIV 3        -0.09              0.72         0.07    -0.01         0.61
# % DIV 3            -0.15             -0.04        -0.29    -0.20         0.14
# TOTAL DIV 4        -0.01              0.68        -0.18    -0.31         0.01
# % DIV 4             0.00             -0.11        -0.53    -0.66        -0.59
# TOTAL DIV 7        -0.34              0.23        -0.04    -0.12         0.01
# % DIV 7            -0.01              0.00        -0.07    -0.08        -0.08
# TOTAL DIV 9         0.18              0.41        -0.13    -0.20        -0.11
# % DIV 9             0.32              0.00        -0.23    -0.30        -0.35
# TOTAL X            -0.13              0.34        -0.08    -0.16        -0.01
# % X                -0.02             -0.11        -0.14    -0.15        -0.18
# FEMALE CANDIDATES   0.03              0.87         0.32     0.16         0.54
# FEMALE TOTAL DIV1  -0.10              0.29         0.87     0.73         0.33
# FEMALE % DIV1       0.02              0.15         0.76     0.85         0.37
# FEMALE TOTAL DIV2  -0.08              0.38         0.50     0.45         0.86
# FEMALE % DIV2      -0.04              0.08         0.28     0.45         0.61
# FEMALE TOTAL DIV3  -0.08              0.57         0.16     0.12         0.65
# FEMALE % DIV3      -0.12              0.00        -0.16    -0.07         0.23
# FEMALE TOTAL DIV4  -0.00              0.67        -0.15    -0.26         0.10
# FEMALE % DIV4      -0.01             -0.09        -0.51    -0.62        -0.54
# FEMALE TOTAL DIV7  -0.42              0.16        -0.02    -0.09         0.02
# FEMALE % DIV7      -0.00             -0.00        -0.05    -0.06        -0.06
# FEMALE TOTAL DIV9   0.16              0.41        -0.13    -0.20        -0.09
# FEMALE % DIV9       0.28             -0.01        -0.22    -0.29        -0.33
# FEMALE TOTAL X     -0.26              0.31        -0.05    -0.14         0.03
# FEMALE % X         -0.03             -0.08        -0.13    -0.14        -0.15
# MALE CANDIDATES    -0.01              0.90         0.29     0.12         0.46
# MALE TOTAL DIV1    -0.07              0.33         0.93     0.77         0.49
# MALE % DIV1         0.02              0.13         0.68     0.88         0.43
# MALE TOTAL DIV2    -0.02              0.50         0.55     0.45         0.82
# MALE % DIV2        -0.06              0.07         0.16     0.33         0.54
# MALE TOTAL DIV3    -0.05              0.67         0.13     0.03         0.57
# MALE % DIV3        -0.10             -0.03        -0.30    -0.26        -0.02
# MALE TOTAL DIV4     0.06              0.62        -0.15    -0.27         0.03
# MALE % DIV4         0.03             -0.08        -0.46    -0.58        -0.54
# MALE TOTAL DIV7    -0.60              0.25        -0.04    -0.12         0.06
# MALE % DIV7        -0.01              0.01        -0.07    -0.09        -0.08
# MALE TOTAL DIV9     0.12              0.35        -0.13    -0.20        -0.12
# MALE % DIV9         0.31              0.01        -0.20    -0.27        -0.31
# MALE TOTAL X       -0.29              0.31        -0.06    -0.14        -0.01
# MALE % X           -0.00             -0.09        -0.13    -0.14        -0.16
#
#                     % DIV 2  TOTAL DIV 3  % DIV 3  TOTAL DIV 4  % DIV 4  ...  \
# YEAR                  -0.07        -0.09    -0.15        -0.01     0.00  ...
# TOTAL CANDIDATES       0.07         0.72    -0.04         0.68    -0.11  ...
# TOTAL DIV 1            0.27         0.07    -0.29        -0.18    -0.53  ...
# % DIV 1                0.47        -0.01    -0.20        -0.31    -0.66  ...
# TOTAL DIV 2            0.67         0.61     0.14         0.01    -0.59  ...
# % DIV 2                1.00         0.21     0.31        -0.35    -0.74  ...
# TOTAL DIV 3            0.21         1.00     0.41         0.52    -0.20  ...
# % DIV 3                0.31         0.41     1.00        -0.16    -0.17  ...
# TOTAL DIV 4           -0.35         0.52    -0.16         1.00     0.39  ...
# % DIV 4               -0.74        -0.20    -0.17         0.39     1.00  ...
# TOTAL DIV 7           -0.11         0.17    -0.02         0.31     0.10  ...
# % DIV 7               -0.13        -0.04    -0.10         0.05     0.07  ...
# TOTAL DIV 9           -0.33         0.09    -0.34         0.57     0.14  ...
# % DIV 9               -0.51        -0.23    -0.45         0.17     0.33  ...
# TOTAL X               -0.20         0.23    -0.11         0.47     0.14  ...
# % X                   -0.20        -0.11    -0.14         0.01     0.08  ...
# FEMALE CANDIDATES      0.15         0.66     0.07         0.57    -0.09  ...
# FEMALE TOTAL DIV1      0.17        -0.02    -0.29        -0.19    -0.43  ...
# FEMALE % DIV1          0.38        -0.02    -0.18        -0.27    -0.54  ...
# FEMALE TOTAL DIV2      0.65         0.39     0.09        -0.14    -0.59  ...
# FEMALE % DIV2          0.86         0.17     0.25        -0.33    -0.66  ...
# FEMALE TOTAL DIV3      0.36         0.85     0.42         0.28    -0.34  ...
# FEMALE % DIV3          0.38         0.37     0.84        -0.18    -0.27  ...
# FEMALE TOTAL DIV4     -0.26         0.56    -0.09         0.93     0.32  ...
# FEMALE % DIV4         -0.67        -0.14    -0.09         0.37     0.93  ...
# FEMALE TOTAL DIV7     -0.06         0.15     0.02         0.21     0.07  ...
# FEMALE % DIV7         -0.08        -0.03    -0.07         0.03     0.05  ...
# FEMALE TOTAL DIV9     -0.32         0.12    -0.31         0.56     0.14  ...
# FEMALE % DIV9         -0.48        -0.22    -0.40         0.15     0.31  ...
# FEMALE TOTAL X        -0.14         0.23    -0.05         0.40     0.12  ...
# FEMALE % X            -0.17        -0.09    -0.11         0.02     0.10  ...
# MALE CANDIDATES        0.03         0.63    -0.04         0.65    -0.01  ...
# MALE TOTAL DIV1        0.29         0.12    -0.22        -0.15    -0.51  ...
# MALE % DIV1            0.50         0.04    -0.11        -0.29    -0.62  ...
# MALE TOTAL DIV2        0.51         0.52     0.06         0.06    -0.50  ...
# MALE % DIV2            0.81         0.22     0.32        -0.26    -0.56  ...
# MALE TOTAL DIV3        0.18         0.85     0.26         0.50    -0.18  ...
# MALE % DIV3            0.04         0.28     0.72        -0.03     0.06  ...
# MALE TOTAL DIV4       -0.32         0.46    -0.18         0.90     0.32  ...
# MALE % DIV4           -0.71        -0.21    -0.26         0.36     0.92  ...
# MALE TOTAL DIV7       -0.08         0.27     0.10         0.31     0.17  ...
# MALE % DIV7           -0.13        -0.03    -0.09         0.06     0.08  ...
# MALE TOTAL DIV9       -0.31         0.06    -0.32         0.48     0.12  ...
# MALE % DIV9           -0.46        -0.21    -0.43         0.15     0.29  ...
# MALE TOTAL X          -0.18         0.19    -0.10         0.40     0.14  ...
# MALE % X              -0.19        -0.11    -0.13         0.01     0.09  ...
#
#                     MALE TOTAL DIV3  MALE % DIV3  MALE TOTAL DIV4  \
# YEAR                          -0.05        -0.10             0.06
# TOTAL CANDIDATES               0.67        -0.03             0.62
# TOTAL DIV 1                    0.13        -0.30            -0.15
# % DIV 1                        0.03        -0.26            -0.27
# TOTAL DIV 2                    0.57        -0.02             0.03
# % DIV 2                        0.18         0.04            -0.32
# TOTAL DIV 3                    0.85         0.28             0.46
# % DIV 3                        0.26         0.72            -0.18
# TOTAL DIV 4                    0.50        -0.03             0.90
# % DIV 4                       -0.18         0.06             0.32
# TOTAL DIV 7                    0.16        -0.01             0.27
# % DIV 7                       -0.03        -0.05             0.04
# TOTAL DIV 9                    0.19        -0.24             0.62
# % DIV 9                       -0.14        -0.26             0.23
# TOTAL X                        0.22        -0.05             0.42
# % X                           -0.09        -0.07             0.01
# FEMALE CANDIDATES              0.53        -0.05             0.50
# FEMALE TOTAL DIV1              0.02        -0.30            -0.16
# FEMALE % DIV1                 -0.01        -0.24            -0.23
# FEMALE TOTAL DIV2              0.33        -0.15            -0.10
# FEMALE % DIV2                  0.10        -0.01            -0.30
# FEMALE TOTAL DIV3              0.62         0.10             0.22
# FEMALE % DIV3                  0.17         0.38            -0.19
# FEMALE TOTAL DIV4              0.51         0.01             0.75
# FEMALE % DIV4                 -0.10         0.20             0.27
# FEMALE TOTAL DIV7              0.13         0.02             0.17
# FEMALE % DIV7                 -0.02        -0.03             0.02
# FEMALE TOTAL DIV9              0.21        -0.20             0.59
# FEMALE % DIV9                 -0.12        -0.20             0.22
# FEMALE TOTAL X                 0.20        -0.02             0.33
# FEMALE % X                    -0.08        -0.03             0.02
# MALE CANDIDATES                0.69         0.07             0.63
# MALE TOTAL DIV1                0.09        -0.27            -0.14
# MALE % DIV1                    0.05        -0.17            -0.28
# MALE TOTAL DIV2                0.55        -0.04             0.07
# MALE % DIV2                    0.20         0.22            -0.30
# MALE TOTAL DIV3                1.00         0.25             0.54
# MALE % DIV3                    0.25         1.00            -0.10
# MALE TOTAL DIV4                0.54        -0.10             1.00
# MALE % DIV4                   -0.20        -0.01             0.33
# MALE TOTAL DIV7                0.03         0.10            -0.02
# MALE % DIV7                   -0.04        -0.05             0.04
# MALE TOTAL DIV9                0.16        -0.25             0.59
# MALE % DIV9                   -0.15        -0.27             0.20
# MALE TOTAL X                   0.16        -0.07             0.28
# MALE % X                      -0.09        -0.06            -0.00
#
#                     MALE % DIV4   MALE TOTAL DIV7   MALE % DIV7  \
# YEAR                        0.03             -0.60        -0.01
# TOTAL CANDIDATES           -0.08              0.25         0.01
# TOTAL DIV 1                -0.46             -0.04        -0.07
# % DIV 1                    -0.58             -0.12        -0.09
# TOTAL DIV 2                -0.54              0.06        -0.08
# % DIV 2                    -0.71             -0.08        -0.13
# TOTAL DIV 3                -0.21              0.27        -0.03
# % DIV 3                    -0.26              0.10        -0.09
# TOTAL DIV 4                 0.36              0.31         0.06
# % DIV 4                     0.92              0.17         0.08
# TOTAL DIV 7                 0.08              0.24         0.38
# % DIV 7                     0.09              0.01         0.83
# TOTAL DIV 9                 0.18             -0.05         0.07
# % DIV 9                     0.39             -0.17         0.10
# TOTAL X                     0.13              0.27         0.08
# % X                         0.10              0.03         0.12
# FEMALE CANDIDATES          -0.11              0.14         0.00
# FEMALE TOTAL DIV1          -0.38             -0.01        -0.06
# FEMALE % DIV1              -0.47             -0.11        -0.07
# FEMALE TOTAL DIV2          -0.54             -0.01        -0.08
# FEMALE % DIV2              -0.61             -0.10        -0.10
# FEMALE TOTAL DIV3          -0.35              0.15        -0.05
# FEMALE % DIV3              -0.28              0.06        -0.08
# FEMALE TOTAL DIV4           0.23              0.23         0.05
# FEMALE % DIV4               0.77              0.18         0.07
# FEMALE TOTAL DIV7           0.05              0.22         0.27
# FEMALE % DIV7               0.07              0.01         0.29
# FEMALE TOTAL DIV9           0.18             -0.06         0.06
# FEMALE % DIV9               0.40             -0.15         0.09
# FEMALE TOTAL X              0.11              0.27         0.07
# FEMALE % X                  0.13              0.04         0.10
# MALE CANDIDATES             0.04              0.30         0.02
# MALE TOTAL DIV1            -0.47             -0.02        -0.07
# MALE % DIV1                -0.56             -0.12        -0.09
# MALE TOTAL DIV2            -0.48             -0.12        -0.07
# MALE % DIV2                -0.55             -0.06        -0.11
# MALE TOTAL DIV3            -0.20              0.03        -0.04
# MALE % DIV3                -0.01              0.10        -0.05
# MALE TOTAL DIV4             0.33             -0.02         0.04
# MALE % DIV4                 1.00              0.15         0.09
# MALE TOTAL DIV7             0.15              1.00        -0.00
# MALE % DIV7                 0.09             -0.00         1.00
# MALE TOTAL DIV9             0.14             -0.11         0.03
# MALE % DIV9                 0.33             -0.17         0.09
# MALE TOTAL X                0.12              0.56         0.08
# MALE % X                    0.09              0.01         0.11
#
#                     MALE TOTAL DIV9   MALE % DIV9  MALE TOTAL X   MALE % X
# YEAR                            0.12         0.31          -0.29     -0.00
# TOTAL CANDIDATES                0.35         0.01           0.31     -0.09
# TOTAL DIV 1                    -0.13        -0.20          -0.06     -0.13
# % DIV 1                        -0.20        -0.27          -0.14     -0.14
# TOTAL DIV 2                    -0.12        -0.31          -0.01     -0.16
# % DIV 2                        -0.31        -0.46          -0.18     -0.19
# TOTAL DIV 3                     0.06        -0.21           0.19     -0.11
# % DIV 3                        -0.32        -0.43          -0.10     -0.13
# TOTAL DIV 4                     0.48         0.15           0.40      0.01
# % DIV 4                         0.12         0.29           0.14      0.09
# TOTAL DIV 7                     0.20        -0.02           0.34      0.05
# % DIV 7                         0.04         0.10           0.07      0.12
# TOTAL DIV 9                     0.94         0.52           0.31      0.04
# % DIV 9                         0.54         0.92           0.09      0.13
# TOTAL X                         0.33         0.10           0.71      0.29
# % X                             0.04         0.10           0.19      0.81
# FEMALE CANDIDATES               0.25        -0.04           0.20     -0.10
# FEMALE TOTAL DIV1              -0.12        -0.18          -0.05     -0.10
# FEMALE % DIV1                  -0.16        -0.21          -0.12     -0.11
# FEMALE TOTAL DIV2              -0.16        -0.29          -0.07     -0.16
# FEMALE % DIV2                  -0.27        -0.38          -0.17     -0.16
# FEMALE TOTAL DIV3              -0.05        -0.27           0.06     -0.13
# FEMALE % DIV3                  -0.29        -0.39          -0.12     -0.12
# FEMALE TOTAL DIV4               0.36         0.07           0.31     -0.02
# FEMALE % DIV4                   0.06         0.24           0.14      0.11
# FEMALE TOTAL DIV7               0.10        -0.07           0.25      0.04
# FEMALE % DIV7                   0.02         0.08           0.04      0.07
# FEMALE TOTAL DIV9               0.79         0.43           0.26      0.04
# FEMALE % DIV9                   0.44         0.73           0.09      0.14
# FEMALE TOTAL X                  0.25         0.01           0.42      0.12
# FEMALE % X                      0.04         0.10           0.11      0.33
# MALE CANDIDATES                 0.38         0.08           0.35     -0.04
# MALE TOTAL DIV1                -0.12        -0.21          -0.04     -0.12
# MALE % DIV1                    -0.21        -0.28          -0.15     -0.13
# MALE TOTAL DIV2                -0.05        -0.25          -0.01     -0.14
# MALE % DIV2                    -0.30        -0.42          -0.17     -0.15
# MALE TOTAL DIV3                 0.16        -0.15           0.16     -0.09
# MALE % DIV3                    -0.25        -0.27          -0.07     -0.06
# MALE TOTAL DIV4                 0.59         0.20           0.28     -0.00
# MALE % DIV4                     0.14         0.33           0.12      0.09
# MALE TOTAL DIV7                -0.11        -0.17           0.56      0.01
# MALE % DIV7                     0.03         0.09           0.08      0.11
# MALE TOTAL DIV9                 1.00         0.54           0.22      0.03
# MALE % DIV9                     0.54         1.00           0.09      0.10
# MALE TOTAL X                    0.22         0.09           1.00      0.25
# MALE % X                        0.03         0.10           0.25      1.00
#
# [46 rows x 46 columns]

# %%
# Use Seaborn to Create a Heatmap
# We can use a Heatmap to Visualize the Correlation Between Variables:
# Import the library seaborn as sns.
# Use the health_data set.
# Use sns.heatmap() to tell Python that we want a heatmap to visualize the correlation matrix.
# Use the correlation matrix. Define the maximal and minimal values of the heatmap. Define that 0 is the center.
# Define the colors with sns.diverging_palette. n=500 means that we want 500 types of color in the same color palette.
# square = True means that we want to see squares.
    
correlation_full_health = health_data.corr()

axis_corr = sns.heatmap(
correlation_full_health,
vmin=-1, vmax=1, center=0,
cmap=sns.diverging_palette(50, 500, n=500),
square=True
)

plt.show()
